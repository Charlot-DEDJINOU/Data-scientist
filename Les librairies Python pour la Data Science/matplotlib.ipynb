# %%
# %matplotlib inline
import numpy as np
from math import exp
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
fig=plt.figure()
ax=plt.axes()
plt.title("Mon premier")
plt.axis([-11,11,0,1500])
x=range(-10,11)
y=[exp(abs(i)) for i in x]
plt.plot(x,y,color="green" ,linestyle="solid",label="green")
plt.plot(x,[exp(abs(i+1)) for i in x],color="yellow",linestyle="solid",label="yellow")
plt.plot(x,[exp(abs(i-1)) for i in x],color="red",linestyle="solid",label="red")
plt.plot(x,[exp(abs(i+2)) for i in x],color="blue",linestyle="solid",label="blue")
plt.plot(x,[exp(abs(i+3)) for i in x])
plt.legend(loc="lower right")

# %%
from math import sin
fig=plt.figure(figsize=(12,12))
x=range(-5,5)
for i in range(2) :
    fig.add_subplot(1,2,i+1)
    plt.style.use(plt.style.available[i])
    plt.scatter(x,[sin(j-i) for j in x])
    plt.text(s=plt.style.available[i],x=10,y=1,color="green")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

prets = pd.read_csv('https://raw.githubusercontent.com/OpenClassrooms-Student-Center/fr-4452741-decouvrez-les-librairies-python-pour-la-data-science/main/data/prets_final.csv')

prets.head()
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non

# %%
#nuage de point
plt.scatter(prets['revenu'] , prets['taux_endettement'] , color='green')

# %%
#circulaire pour voir le nombre des clients en risque
clients_risque = prets.loc[prets['risque'] == 'Oui'].shape[0]

clients_non_risque = prets.shape[0] - clients_risque

plt.pie(x=[clients_risque , clients_non_risque] , labels=['En risque' , 'Pas de risque'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2454ae124f0>,
# ...
#  [Text(0.8072739036488451, 0.7472006721674943, 'En risque'),
#   Text(-0.8072739386278321, -0.7472006343762746, 'Pas de risque')])

# %%
#En bar pour voir le nombre des clients en risque
plt.bar(height=[clients_risque , clients_non_risque] , x=['En risque' , 'Pas de risque'])
# Out:
# <BarContainer object of 2 artists>

# %%
#nuage de point pour tous les agence : le taux_interet en fonction du revenu

for ville in prets['ville'].unique() :
    df = prets.loc[prets['ville'] == ville , :]
    plt.scatter(df['revenu'] , df['taux_interet'] , label = ville)
    
plt.legend()
plt.show()

# %%
# Out:
#    identifiant      ville     CP  revenu  remboursement  duree        type  \
# 0            0   TOULOUSE  31100  3669.0        1130.05    240  immobilier
# 1            1      PARIS  75009  5310.0         240.00     64  automobile
# 2            1      PARIS  75009  5310.0        1247.85    300  immobilier
# 3            2  MARSEILLE  13010  1873.0         552.54    240  immobilier
# 4            3  MARSEILLE  13010  1684.0         586.03    180  immobilier
#
#    taux_interet  taux_endettement  cout_total  benefices risque
# 0         1.168             30.80    271212.0     131.99    Non
# 1         3.701              4.52     15360.0      23.69    Non
# 2         1.173             23.50    374355.0     182.97    Non
# 3         0.972             29.50    132609.6      53.71    Non
# 4         1.014             34.80    105485.4      44.57    Non

# %%
sns.scatterplot(data=prets, x='revenu', y='taux_endettement', hue='type' , size='duree')
# Out:
# <AxesSubplot:xlabel='revenu', ylabel='taux_endettement'>

# %%
# création d'une Series de 4 dates
dates = pd.to_datetime(['2021-01-01', '2021-05-01', '2021-09-01', '2022-01-01'])

# création de 3 listes Y1, Y2 et Y3
Y1 = [120, 560, 1760, 1860]
Y2 = [300, 365, 100, 490]
Y3 = [300, 790, 1130, 1400]

plt.figure()
plt.plot(dates, Y1, label='a')
plt.plot(dates, Y2, label='b')
plt.plot(dates, Y3, label='c')
plt.legend()
plt.show()

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.barplot(data=iris, x='species', y='petal_width', ci=None, estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
mpg = sns.load_dataset('mpg')

sns.set_theme()
origin_count = mpg['origin'].value_counts().reset_index()
plt.pie(labels=origin_count['index'], x=origin_count['origin'], autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2454b4e0490>,
# ...
#  [Text(-0.42295633254055504, 1.015434853037773, 'usa'),
#   Text(-0.17293561388226758, -1.0863209808574827, 'japan'),
#   Text(0.9363126752779499, -0.5773374871891209, 'europe')],
#  [Text(-0.23070345411303, 0.5538735562024215, '62.6%'),
#   Text(-0.09432851666305503, -0.5925387168313542, '19.8%'),
#   Text(0.5107160046970636, -0.3149113566486114, '17.6%')])
